# %%
import glob as glob
import os
import pandas as pd

from kaggle import data

# %%
csv=data.import_csv('dataset')

# %%
csv
# Out:
#           id                                              title  \
# 0          1       What are some Caribbean cruises for October?
# 1          2  How can I find a guide that will take me safel...
# 2          4  Does Singapore Airlines offer any reward seats...
# 3          5  What is the easiest transportation to use thro...
# 4          6                        How can I visit Antarctica?
# 5          8    Best way to get from SeaTac airport to Redmond?
# 6          9  What are must-visit destinations for the first...
# 7         10  When traveling to a country with a different c...
# 8         11  What is the best way to obtain visas for the T...
# 9         13  Where can I find up-to-date information about ...
# 10        14  Is it advisable for US citizen to attempt a vi...
# 11        15  What are some of the sights to see in Budapest...
# 12        16  Is there a good website to plan a trip via tra...
# 13        25  What are the best ways to avoid data roaming f...
# 14        26  What should I know about "Around The World" fl...
# 15        27  What are some good ways to find things to expl...
# 16        28                 Cheapest mobile operator in Europe
# 17        31                         Sightseeing the USA by air
# 18        33  Online resources/communities especially for tr...
# 19        34  What kind of questions should I be asking abou...
# 20        41                  Where to find good cave-swimming?
# 21        45  Are there advantages to using private car serv...
# 22        47  Are there caves and tunnels under Tallinn, Est...
# 23        66  Is it possible to get a permit to travel to Ti...
# 24        67           What is there to do in Orlando, Florida?
# 25        69  How bad is baggage theft at Johannesburg airport?
# 26        73  Is it safe to travel in Japan considering the ...
# 27        77                           Flight deals from the UK
# 28        78    Tel Aviv a good base to see Israel & Palestine?
# 29        79      Something to do in or around Colmar in France
# ...      ...                                                ...
# 10402  39704                 Key extraction from Plaintext+CMAC
# 10403  39707  Problems when using PBKDF2 to create an ECDSA ...
# 10404  39710           Does AugPake not require key stretching?
# 10405  39711      How exactly does plaintext become ciphertext?
# 10406  39715  Is it safe to use a SSH server keys for a SSH ...
# 10407  39721  What is the next number of this lottery sequence?
# 10408  39722  Hi.. all! CP-ABE implementation in cloud compu...
# 10409  39725  Same-length plaintext results in predictable c...
# 10410  39726  Is there a Fernet implementation for Java or C...
# 10411  39728      Authenticating a message with HMAC vs AES-CBC
# 10412  39730  Help with terms: hash function and a pseudoran...
# 10413  39731    Does passphrase length impact read-write speed?
# 10414  39735          What's a cryptographic primitive, really?
# 10415  39736  Is there a signature scheme in which private k...
# 10416  39737  How to compare security between S-Box and Addi...
# 10417  39739              Selecting an appropriate key for HMAC
# 10418  39741  In A5/1 stream cipher, why are the specific bi...
# 10419  39742          How effective is Serpent-256 in CTR mode?
# 10420  39743                       PBKDF2WithHmacSHA512 in Java
# 10421  39746        Why standard deviation of BLISS is so high?
# 10422  39750    Surely the best Hash would be one nobody knows?
# 10423  39752  Is it possible to use RSA with AEAD operation ...
# 10424  39753  is it possible to extract a "hint hash" of som...
# 10425  39754  Could someone help me to decipher this? I beli...
# 10426  39757                     RSA - twin primes, two modulus
# 10427  39758     Prevent hash collisions with HMAC secret as IV
# 10428  39759  Can a modified executable file be padded to gi...
# 10429  39761                             Definitions of secrecy
# 10430  39762                                 What is a ratchet?
# 10431  39768          Encrypting 256 bit AES keys with AES ECB?
#
#                                                  content  \
# 0      <p>My fiancée and I are looking for a good Car...
# 1      <p>This was one of our definition questions, b...
# 2      <p>Singapore Airlines has an all-business clas...
# 3      <p>Another definition question that interested...
# 4      <p>A year ago I was reading some magazine, and...
# 5      <p>Can anyone suggest the best way to get from...
# 6      <p>We are considering visiting Argentina for u...
# 7      <p>Recently my wife and I traveled to Italy an...
# 8      <p>I'm planning on taking the trans-Siberian /...
# 9      <p>I need to travel from Cusco, Peru to La Paz...
# 10     <p>I am aware of travel agencies catering to U...
# 11     <p>I'm planning my first international trip ou...
# 12     <p>My wife and I have decided to move across E...
# 13     <p>I'm looking for data plans I can use while ...
# 14     <p>I have heard rumours of such things, and ha...
# 15     <p>When traveling, one of my favorite things t...
# 16     <blockquote>\n  <p><strong>Possible Duplicate:...
# 17     <p>The next time family from overseas comes to...
# 18     <p>I'm dreaming of visiting remote islands suc...
# 19     <p>Tropical destinations have to be one of the...
# 20     <p>I'd love to travel to a place that has a go...
# 21     <p>When planning a trip I've seen people say p...
# 22     <p>This spring I was in Tallinn, and I heard a...
# 23     <p>I am confused about how I go about getting ...
# 24     <p>Aside from the Disney World, what else is t...
# 25     <p>South Africa's Johannesburg's airport has a...
# 26     <p>Are there any areas that should be avoided ...
# 27     <p>Can someone recommend a good website with f...
# 28     <p>I'm planning to spend 3 weeks in Israel &am...
# 29     <p>My wife and I will be travelling to Colmar ...
# ...                                                  ...
# 10402  <p>Can leakage of a plaintext and correspondin...
# 10403  <p>System based on, e.g.:<br>\nPBKDF2, ECDSA a...
# 10404  <p>I was reading the <a href="https://datatrac...
# 10405  <p>I'm having a hard time finding out how Plai...
# 10406  <p>Let me explain my question. I am working on...
# 10407  <p>1469356\n352428\n1413795\n1656764\n347481\n...
# 10408  <p>I want to know how to implement (deploy)  C...
# 10409  <p>I started with a basic mixed-monoalphabetic...
# 10410  <p>I want to encrypt user data and exchange it...
# 10411  <p>Given some string <code>s</code> I want to ...
# 10412  <p>I am a little bit confused about the terms ...
# 10413  <p>I'm using <a href="https://diskcryptor.net/...
# 10414  <p>The more I encounter the term "cryptographi...
# 10415  <p>Normally in a signature system, the private...
# 10416  <p>I'm studying a block cipher based on ARX(Ad...
# 10417  <p>I'm writing a symmetric encryption scheme f...
# 10418  <p>My two part question is:</p>\n\n<p>1) How a...
# 10419  <p>I downloaded a compression program known as...
# 10420  <p>I want to encrypt password with PBKDF2WithH...
# 10421  <p>In lattice based digital signature scheme B...
# 10422  <p>I'm very confused as to why companys use co...
# 10423  <p>Some research shows that RSA is commonly us...
# 10424  <p>I'm a web developer starting to dip into cr...
# 10425  <p>I have a cipher I have been attempting to s...
# 10426  <p>I'm working on this problem. I'm given </p>...
# 10427  <p>Our organistation would like to hash large ...
# 10428  <p>MD5 or SHA1 checksums seem to be the gold s...
# 10429  <p>I found terms like "forward secrecy", "futu...
# 10430  <p>while reading Whatsapp's Security Whitepape...
# 10431  <p>What are the pros/cons of using AES ECB mod...
#
#                                                     tags           file_name
# 0                           caribbean cruising vacations  dataset/travel.csv
# 1      guides extreme-tourism amazon-river amazon-jungle  dataset/travel.csv
# 2      loyalty-programs routes ewr singapore-airlines...  dataset/travel.csv
# 3                                 romania transportation  dataset/travel.csv
# 4                             extreme-tourism antarctica  dataset/travel.csv
# 5                     usa airport-transfer taxis seattle  dataset/travel.csv
# 6      sightseeing public-transport transportation ar...  dataset/travel.csv
# 7             safety international-travel money exchange  dataset/travel.csv
# 8             russia visas china mongolia trans-siberian  dataset/travel.csv
# 9      online-resources transportation peru south-ame...  dataset/travel.csv
# 10                        us-citizens travel-agents cuba  dataset/travel.csv
# 11                          sightseeing hungary budapest  dataset/travel.csv
# 12        europe online-resources planning guides trains  dataset/travel.csv
# 13     budget cellphones data-plans communication mob...  dataset/travel.csv
# 14                           air-travel around-the-world  dataset/travel.csv
# 15                    sightseeing planning tourist-traps  dataset/travel.csv
# 16             budget europe cellphones mobile-operators  dataset/travel.csv
# 17                      air-travel usa sightseeing tours  dataset/travel.csv
# 18     online-resources international-travel adventur...  dataset/travel.csv
# 19                        planning tropical-destinations  dataset/travel.csv
# 20      destinations adventure activities swimming caves  dataset/travel.csv
# 21     transportation taxis automobiles airport-transfer  dataset/travel.csv
# 22                     sightseeing estonia tallinn caves  dataset/travel.csv
# 23                            china trains permits tibet  dataset/travel.csv
# 24                                   usa florida orlando  dataset/travel.csv
# 25            luggage airports security south-africa jnb  dataset/travel.csv
# 26                         health japan safety radiation  dataset/travel.csv
# 27        air-travel budget online-resources uk airlines  dataset/travel.csv
# 28               israel accommodation palestine tel-aviv  dataset/travel.csv
# 29                                       france children  dataset/travel.csv
# ...                                                  ...                 ...
# 10402                             aes cryptanalysis cmac  dataset/crypto.csv
# 10403  public-key cryptanalysis elliptic-curves authe...  dataset/crypto.csv
# 10404                           password-hashing augpake  dataset/crypto.csv
# 10405                      encryption rsa public-key pgp  dataset/crypto.csv
# 10406                             rsa public-key tls ssh  dataset/crypto.csv
# 10407                                         randomness  dataset/crypto.csv
# 10408                                     implementation  dataset/crypto.csv
# 10409                      symmetric substitution-cipher  dataset/crypto.csv
# 10410                               encryption symmetric  dataset/crypto.csv
# 10411                                 signature hmac mac  dataset/crypto.csv
# 10412       hash hmac pseudo-random-function terminology  dataset/crypto.csv
# 10413                           key-size disk-encryption  dataset/crypto.csv
# 10414                       algorithm-design terminology  dataset/crypto.csv
# 10415                               public-key signature  dataset/crypto.csv
# 10416                                       block-cipher  dataset/crypto.csv
# 10417                                       aes keys mac  dataset/crypto.csv
# 10418                                         encryption  dataset/crypto.csv
# 10419    encryption symmetric modes-of-operation serpent  dataset/crypto.csv
# 10420                                               java  dataset/crypto.csv
# 10421  signature post-quantum-cryptography lattice-cr...  dataset/crypto.csv
# 10422                                               hash  dataset/crypto.csv
# 10423                             rsa modes-of-operation  dataset/crypto.csv
# 10424                                               hash  dataset/crypto.csv
# 10425                                      cryptanalysis  dataset/crypto.csv
# 10426                    rsa cryptanalysis prime-numbers  dataset/crypto.csv
# 10427                     hash hmac collision-resistance  dataset/crypto.csv
# 10428                                       hash padding  dataset/crypto.csv
# 10429                    perfect-secrecy forward-secrecy  dataset/crypto.csv
# 10430                                hash diffie-hellman  dataset/crypto.csv
# 10431                  encryption aes symmetric key-wrap  dataset/crypto.csv
#
# [87000 rows x 5 columns]

# %%
csv.drop('id', axis=1)
# Out:
#                                                    title  \
# 0           What are some Caribbean cruises for October?
# 1      How can I find a guide that will take me safel...
# 2      Does Singapore Airlines offer any reward seats...
# 3      What is the easiest transportation to use thro...
# 4                            How can I visit Antarctica?
# 5        Best way to get from SeaTac airport to Redmond?
# 6      What are must-visit destinations for the first...
# 7      When traveling to a country with a different c...
# 8      What is the best way to obtain visas for the T...
# 9      Where can I find up-to-date information about ...
# 10     Is it advisable for US citizen to attempt a vi...
# 11     What are some of the sights to see in Budapest...
# 12     Is there a good website to plan a trip via tra...
# 13     What are the best ways to avoid data roaming f...
# 14     What should I know about "Around The World" fl...
# 15     What are some good ways to find things to expl...
# 16                    Cheapest mobile operator in Europe
# 17                            Sightseeing the USA by air
# 18     Online resources/communities especially for tr...
# 19     What kind of questions should I be asking abou...
# 20                     Where to find good cave-swimming?
# 21     Are there advantages to using private car serv...
# 22     Are there caves and tunnels under Tallinn, Est...
# 23     Is it possible to get a permit to travel to Ti...
# 24              What is there to do in Orlando, Florida?
# 25     How bad is baggage theft at Johannesburg airport?
# 26     Is it safe to travel in Japan considering the ...
# 27                              Flight deals from the UK
# 28       Tel Aviv a good base to see Israel & Palestine?
# 29         Something to do in or around Colmar in France
# ...                                                  ...
# 10402                 Key extraction from Plaintext+CMAC
# 10403  Problems when using PBKDF2 to create an ECDSA ...
# 10404           Does AugPake not require key stretching?
# 10405      How exactly does plaintext become ciphertext?
# 10406  Is it safe to use a SSH server keys for a SSH ...
# 10407  What is the next number of this lottery sequence?
# 10408  Hi.. all! CP-ABE implementation in cloud compu...
# 10409  Same-length plaintext results in predictable c...
# 10410  Is there a Fernet implementation for Java or C...
# 10411      Authenticating a message with HMAC vs AES-CBC
# 10412  Help with terms: hash function and a pseudoran...
# 10413    Does passphrase length impact read-write speed?
# 10414          What's a cryptographic primitive, really?
# 10415  Is there a signature scheme in which private k...
# 10416  How to compare security between S-Box and Addi...
# 10417              Selecting an appropriate key for HMAC
# 10418  In A5/1 stream cipher, why are the specific bi...
# 10419          How effective is Serpent-256 in CTR mode?
# 10420                       PBKDF2WithHmacSHA512 in Java
# 10421        Why standard deviation of BLISS is so high?
# 10422    Surely the best Hash would be one nobody knows?
# 10423  Is it possible to use RSA with AEAD operation ...
# 10424  is it possible to extract a "hint hash" of som...
# 10425  Could someone help me to decipher this? I beli...
# 10426                     RSA - twin primes, two modulus
# 10427     Prevent hash collisions with HMAC secret as IV
# 10428  Can a modified executable file be padded to gi...
# 10429                             Definitions of secrecy
# 10430                                 What is a ratchet?
# 10431          Encrypting 256 bit AES keys with AES ECB?
#
#                                                  content  \
# 0      <p>My fiancée and I are looking for a good Car...
# 1      <p>This was one of our definition questions, b...
# 2      <p>Singapore Airlines has an all-business clas...
# 3      <p>Another definition question that interested...
# 4      <p>A year ago I was reading some magazine, and...
# 5      <p>Can anyone suggest the best way to get from...
# 6      <p>We are considering visiting Argentina for u...
# 7      <p>Recently my wife and I traveled to Italy an...
# 8      <p>I'm planning on taking the trans-Siberian /...
# 9      <p>I need to travel from Cusco, Peru to La Paz...
# 10     <p>I am aware of travel agencies catering to U...
# 11     <p>I'm planning my first international trip ou...
# 12     <p>My wife and I have decided to move across E...
# 13     <p>I'm looking for data plans I can use while ...
# 14     <p>I have heard rumours of such things, and ha...
# 15     <p>When traveling, one of my favorite things t...
# 16     <blockquote>\n  <p><strong>Possible Duplicate:...
# 17     <p>The next time family from overseas comes to...
# 18     <p>I'm dreaming of visiting remote islands suc...
# 19     <p>Tropical destinations have to be one of the...
# 20     <p>I'd love to travel to a place that has a go...
# 21     <p>When planning a trip I've seen people say p...
# 22     <p>This spring I was in Tallinn, and I heard a...
# 23     <p>I am confused about how I go about getting ...
# 24     <p>Aside from the Disney World, what else is t...
# 25     <p>South Africa's Johannesburg's airport has a...
# 26     <p>Are there any areas that should be avoided ...
# 27     <p>Can someone recommend a good website with f...
# 28     <p>I'm planning to spend 3 weeks in Israel &am...
# 29     <p>My wife and I will be travelling to Colmar ...
# ...                                                  ...
# 10402  <p>Can leakage of a plaintext and correspondin...
# 10403  <p>System based on, e.g.:<br>\nPBKDF2, ECDSA a...
# 10404  <p>I was reading the <a href="https://datatrac...
# 10405  <p>I'm having a hard time finding out how Plai...
# 10406  <p>Let me explain my question. I am working on...
# 10407  <p>1469356\n352428\n1413795\n1656764\n347481\n...
# 10408  <p>I want to know how to implement (deploy)  C...
# 10409  <p>I started with a basic mixed-monoalphabetic...
# 10410  <p>I want to encrypt user data and exchange it...
# 10411  <p>Given some string <code>s</code> I want to ...
# 10412  <p>I am a little bit confused about the terms ...
# 10413  <p>I'm using <a href="https://diskcryptor.net/...
# 10414  <p>The more I encounter the term "cryptographi...
# 10415  <p>Normally in a signature system, the private...
# 10416  <p>I'm studying a block cipher based on ARX(Ad...
# 10417  <p>I'm writing a symmetric encryption scheme f...
# 10418  <p>My two part question is:</p>\n\n<p>1) How a...
# 10419  <p>I downloaded a compression program known as...
# 10420  <p>I want to encrypt password with PBKDF2WithH...
# 10421  <p>In lattice based digital signature scheme B...
# 10422  <p>I'm very confused as to why companys use co...
# 10423  <p>Some research shows that RSA is commonly us...
# 10424  <p>I'm a web developer starting to dip into cr...
# 10425  <p>I have a cipher I have been attempting to s...
# 10426  <p>I'm working on this problem. I'm given </p>...
# 10427  <p>Our organistation would like to hash large ...
# 10428  <p>MD5 or SHA1 checksums seem to be the gold s...
# 10429  <p>I found terms like "forward secrecy", "futu...
# 10430  <p>while reading Whatsapp's Security Whitepape...
# 10431  <p>What are the pros/cons of using AES ECB mod...
#
#                                                     tags           file_name
# 0                           caribbean cruising vacations  dataset/travel.csv
# 1      guides extreme-tourism amazon-river amazon-jungle  dataset/travel.csv
# 2      loyalty-programs routes ewr singapore-airlines...  dataset/travel.csv
# 3                                 romania transportation  dataset/travel.csv
# 4                             extreme-tourism antarctica  dataset/travel.csv
# 5                     usa airport-transfer taxis seattle  dataset/travel.csv
# 6      sightseeing public-transport transportation ar...  dataset/travel.csv
# 7             safety international-travel money exchange  dataset/travel.csv
# 8             russia visas china mongolia trans-siberian  dataset/travel.csv
# 9      online-resources transportation peru south-ame...  dataset/travel.csv
# 10                        us-citizens travel-agents cuba  dataset/travel.csv
# 11                          sightseeing hungary budapest  dataset/travel.csv
# 12        europe online-resources planning guides trains  dataset/travel.csv
# 13     budget cellphones data-plans communication mob...  dataset/travel.csv
# 14                           air-travel around-the-world  dataset/travel.csv
# 15                    sightseeing planning tourist-traps  dataset/travel.csv
# 16             budget europe cellphones mobile-operators  dataset/travel.csv
# 17                      air-travel usa sightseeing tours  dataset/travel.csv
# 18     online-resources international-travel adventur...  dataset/travel.csv
# 19                        planning tropical-destinations  dataset/travel.csv
# 20      destinations adventure activities swimming caves  dataset/travel.csv
# 21     transportation taxis automobiles airport-transfer  dataset/travel.csv
# 22                     sightseeing estonia tallinn caves  dataset/travel.csv
# 23                            china trains permits tibet  dataset/travel.csv
# 24                                   usa florida orlando  dataset/travel.csv
# 25            luggage airports security south-africa jnb  dataset/travel.csv
# 26                         health japan safety radiation  dataset/travel.csv
# 27        air-travel budget online-resources uk airlines  dataset/travel.csv
# 28               israel accommodation palestine tel-aviv  dataset/travel.csv
# 29                                       france children  dataset/travel.csv
# ...                                                  ...                 ...
# 10402                             aes cryptanalysis cmac  dataset/crypto.csv
# 10403  public-key cryptanalysis elliptic-curves authe...  dataset/crypto.csv
# 10404                           password-hashing augpake  dataset/crypto.csv
# 10405                      encryption rsa public-key pgp  dataset/crypto.csv
# 10406                             rsa public-key tls ssh  dataset/crypto.csv
# 10407                                         randomness  dataset/crypto.csv
# 10408                                     implementation  dataset/crypto.csv
# 10409                      symmetric substitution-cipher  dataset/crypto.csv
# 10410                               encryption symmetric  dataset/crypto.csv
# 10411                                 signature hmac mac  dataset/crypto.csv
# 10412       hash hmac pseudo-random-function terminology  dataset/crypto.csv
# 10413                           key-size disk-encryption  dataset/crypto.csv
# 10414                       algorithm-design terminology  dataset/crypto.csv
# 10415                               public-key signature  dataset/crypto.csv
# 10416                                       block-cipher  dataset/crypto.csv
# 10417                                       aes keys mac  dataset/crypto.csv
# 10418                                         encryption  dataset/crypto.csv
# 10419    encryption symmetric modes-of-operation serpent  dataset/crypto.csv
# 10420                                               java  dataset/crypto.csv
# 10421  signature post-quantum-cryptography lattice-cr...  dataset/crypto.csv
# 10422                                               hash  dataset/crypto.csv
# 10423                             rsa modes-of-operation  dataset/crypto.csv
# 10424                                               hash  dataset/crypto.csv
# 10425                                      cryptanalysis  dataset/crypto.csv
# 10426                    rsa cryptanalysis prime-numbers  dataset/crypto.csv
# 10427                     hash hmac collision-resistance  dataset/crypto.csv
# 10428                                       hash padding  dataset/crypto.csv
# 10429                    perfect-secrecy forward-secrecy  dataset/crypto.csv
# 10430                                hash diffie-hellman  dataset/crypto.csv
# 10431                  encryption aes symmetric key-wrap  dataset/crypto.csv
#
# [87000 rows x 4 columns]

# %%
from bs4 import BeautifulSoup

# %%
csv.content = csv.content.apply(lambda x: BeautifulSoup(x, "lxml").text.replace('\n', ' '))

# %%
csv.file_name = csv.file_name.str.replace('dataset/', '').str.replace('.csv', '')

# %%
csv
# Out:
#           id                                              title  \
# 0          1       What are some Caribbean cruises for October?
# 1          2  How can I find a guide that will take me safel...
# 2          4  Does Singapore Airlines offer any reward seats...
# 3          5  What is the easiest transportation to use thro...
# 4          6                        How can I visit Antarctica?
# 5          8    Best way to get from SeaTac airport to Redmond?
# 6          9  What are must-visit destinations for the first...
# 7         10  When traveling to a country with a different c...
# 8         11  What is the best way to obtain visas for the T...
# 9         13  Where can I find up-to-date information about ...
# 10        14  Is it advisable for US citizen to attempt a vi...
# 11        15  What are some of the sights to see in Budapest...
# 12        16  Is there a good website to plan a trip via tra...
# 13        25  What are the best ways to avoid data roaming f...
# 14        26  What should I know about "Around The World" fl...
# 15        27  What are some good ways to find things to expl...
# 16        28                 Cheapest mobile operator in Europe
# 17        31                         Sightseeing the USA by air
# 18        33  Online resources/communities especially for tr...
# 19        34  What kind of questions should I be asking abou...
# 20        41                  Where to find good cave-swimming?
# 21        45  Are there advantages to using private car serv...
# 22        47  Are there caves and tunnels under Tallinn, Est...
# 23        66  Is it possible to get a permit to travel to Ti...
# 24        67           What is there to do in Orlando, Florida?
# 25        69  How bad is baggage theft at Johannesburg airport?
# 26        73  Is it safe to travel in Japan considering the ...
# 27        77                           Flight deals from the UK
# 28        78    Tel Aviv a good base to see Israel & Palestine?
# 29        79      Something to do in or around Colmar in France
# ...      ...                                                ...
# 10402  39704                 Key extraction from Plaintext+CMAC
# 10403  39707  Problems when using PBKDF2 to create an ECDSA ...
# 10404  39710           Does AugPake not require key stretching?
# 10405  39711      How exactly does plaintext become ciphertext?
# 10406  39715  Is it safe to use a SSH server keys for a SSH ...
# 10407  39721  What is the next number of this lottery sequence?
# 10408  39722  Hi.. all! CP-ABE implementation in cloud compu...
# 10409  39725  Same-length plaintext results in predictable c...
# 10410  39726  Is there a Fernet implementation for Java or C...
# 10411  39728      Authenticating a message with HMAC vs AES-CBC
# 10412  39730  Help with terms: hash function and a pseudoran...
# 10413  39731    Does passphrase length impact read-write speed?
# 10414  39735          What's a cryptographic primitive, really?
# 10415  39736  Is there a signature scheme in which private k...
# 10416  39737  How to compare security between S-Box and Addi...
# 10417  39739              Selecting an appropriate key for HMAC
# 10418  39741  In A5/1 stream cipher, why are the specific bi...
# 10419  39742          How effective is Serpent-256 in CTR mode?
# 10420  39743                       PBKDF2WithHmacSHA512 in Java
# 10421  39746        Why standard deviation of BLISS is so high?
# 10422  39750    Surely the best Hash would be one nobody knows?
# 10423  39752  Is it possible to use RSA with AEAD operation ...
# 10424  39753  is it possible to extract a "hint hash" of som...
# 10425  39754  Could someone help me to decipher this? I beli...
# 10426  39757                     RSA - twin primes, two modulus
# 10427  39758     Prevent hash collisions with HMAC secret as IV
# 10428  39759  Can a modified executable file be padded to gi...
# 10429  39761                             Definitions of secrecy
# 10430  39762                                 What is a ratchet?
# 10431  39768          Encrypting 256 bit AES keys with AES ECB?
#
#                                                  content  \
# 0      My fiancée and I are looking for a good Caribb...
# 1      This was one of our definition questions, but ...
# 2      Singapore Airlines has an all-business class f...
# 3      Another definition question that interested me...
# 4      A year ago I was reading some magazine, and fo...
# 5      Can anyone suggest the best way to get from Se...
# 6      We are considering visiting Argentina for up t...
# 7      Recently my wife and I traveled to Italy and b...
# 8      I'm planning on taking the trans-Siberian / tr...
# 9      I need to travel from Cusco, Peru to La Paz, B...
# 10     I am aware of travel agencies catering to US c...
# 11     I'm planning my first international trip out o...
# 12     My wife and I have decided to move across Euro...
# 13     I'm looking for data plans I can use while tou...
# 14     I have heard rumours of such things, and have ...
# 15     When traveling, one of my favorite things to d...
# 16      Possible Duplicate: What are the best ways to...
# 17     The next time family from overseas comes to vi...
# 18     I'm dreaming of visiting remote islands such a...
# 19     Tropical destinations have to be one of the mo...
# 20     I'd love to travel to a place that has a good ...
# 21     When planning a trip I've seen people say priv...
# 22     This spring I was in Tallinn, and I heard abou...
# 23     I am confused about how I go about getting a p...
# 24     Aside from the Disney World, what else is ther...
# 25     South Africa's Johannesburg's airport has a re...
# 26     Are there any areas that should be avoided and...
# 27     Can someone recommend a good website with flig...
# 28     I'm planning to spend 3 weeks in Israel & Pale...
# 29     My wife and I will be travelling to Colmar in ...
# ...                                                  ...
# 10402  Can leakage of a plaintext and corresponding a...
# 10403  System based on, e.g.: PBKDF2, ECDSA and authe...
# 10404  I was reading the AugPAKE rfc and noticed that...
# 10405  I'm having a hard time finding out how PlainTe...
# 10406  Let me explain my question. I am working on an...
# 10407  1469356 352428 1413795 1656764 347481 246721 1...
# 10408  I want to know how to implement (deploy)  CP-A...
# 10409  I started with a basic mixed-monoalphabetic su...
# 10410  I want to encrypt user data and exchange it be...
# 10411  Given some string s I want to sign, are follow...
# 10412  I am a little bit confused about the terms has...
# 10413  I'm using Diskcryptor to encrypt a 2TB externa...
# 10414  The more I encounter the term "cryptographic p...
# 10415  Normally in a signature system, the private ke...
# 10416  I'm studying a block cipher based on ARX(Addit...
# 10417  I'm writing a symmetric encryption scheme for ...
# 10418  My two part question is: 1) How are bit positi...
# 10419  I downloaded a compression program known as Pe...
# 10420  I want to encrypt password with PBKDF2WithHmac...
# 10421  In lattice based digital signature scheme BLIS...
# 10422  I'm very confused as to why companys use commo...
# 10423  Some research shows that RSA is commonly used ...
# 10424  I'm a web developer starting to dip into crypt...
# 10425  I have a cipher I have been attempting to solv...
# 10426  I'm working on this problem. I'm given  $\begi...
# 10427  Our organistation would like to hash large fil...
# 10428  MD5 or SHA1 checksums seem to be the gold stan...
# 10429  I found terms like "forward secrecy", "future ...
# 10430  while reading Whatsapp's Security Whitepaper I...
# 10431  What are the pros/cons of using AES ECB mode t...
#
#                                                     tags file_name
# 0                           caribbean cruising vacations    travel
# 1      guides extreme-tourism amazon-river amazon-jungle    travel
# 2      loyalty-programs routes ewr singapore-airlines...    travel
# 3                                 romania transportation    travel
# 4                             extreme-tourism antarctica    travel
# 5                     usa airport-transfer taxis seattle    travel
# 6      sightseeing public-transport transportation ar...    travel
# 7             safety international-travel money exchange    travel
# 8             russia visas china mongolia trans-siberian    travel
# 9      online-resources transportation peru south-ame...    travel
# 10                        us-citizens travel-agents cuba    travel
# 11                          sightseeing hungary budapest    travel
# 12        europe online-resources planning guides trains    travel
# 13     budget cellphones data-plans communication mob...    travel
# 14                           air-travel around-the-world    travel
# 15                    sightseeing planning tourist-traps    travel
# 16             budget europe cellphones mobile-operators    travel
# 17                      air-travel usa sightseeing tours    travel
# 18     online-resources international-travel adventur...    travel
# 19                        planning tropical-destinations    travel
# 20      destinations adventure activities swimming caves    travel
# 21     transportation taxis automobiles airport-transfer    travel
# 22                     sightseeing estonia tallinn caves    travel
# 23                            china trains permits tibet    travel
# 24                                   usa florida orlando    travel
# 25            luggage airports security south-africa jnb    travel
# 26                         health japan safety radiation    travel
# 27        air-travel budget online-resources uk airlines    travel
# 28               israel accommodation palestine tel-aviv    travel
# 29                                       france children    travel
# ...                                                  ...       ...
# 10402                             aes cryptanalysis cmac    crypto
# 10403  public-key cryptanalysis elliptic-curves authe...    crypto
# 10404                           password-hashing augpake    crypto
# 10405                      encryption rsa public-key pgp    crypto
# 10406                             rsa public-key tls ssh    crypto
# 10407                                         randomness    crypto
# 10408                                     implementation    crypto
# 10409                      symmetric substitution-cipher    crypto
# 10410                               encryption symmetric    crypto
# 10411                                 signature hmac mac    crypto
# 10412       hash hmac pseudo-random-function terminology    crypto
# 10413                           key-size disk-encryption    crypto
# 10414                       algorithm-design terminology    crypto
# 10415                               public-key signature    crypto
# 10416                                       block-cipher    crypto
# 10417                                       aes keys mac    crypto
# 10418                                         encryption    crypto
# 10419    encryption symmetric modes-of-operation serpent    crypto
# 10420                                               java    crypto
# 10421  signature post-quantum-cryptography lattice-cr...    crypto
# 10422                                               hash    crypto
# 10423                             rsa modes-of-operation    crypto
# 10424                                               hash    crypto
# 10425                                      cryptanalysis    crypto
# 10426                    rsa cryptanalysis prime-numbers    crypto
# 10427                     hash hmac collision-resistance    crypto
# 10428                                       hash padding    crypto
# 10429                    perfect-secrecy forward-secrecy    crypto
# 10430                                hash diffie-hellman    crypto
# 10431                  encryption aes symmetric key-wrap    crypto
#
# [87000 rows x 5 columns]

# %%
csv = data.get_data('dataset')

# %%
csv
# Out:
#           id                                              title  \
# 0          1       What are some Caribbean cruises for October?
# 1          2  How can I find a guide that will take me safel...
# 2          4  Does Singapore Airlines offer any reward seats...
# 3          5  What is the easiest transportation to use thro...
# 4          6                        How can I visit Antarctica?
# 5          8    Best way to get from SeaTac airport to Redmond?
# 6          9  What are must-visit destinations for the first...
# 7         10  When traveling to a country with a different c...
# 8         11  What is the best way to obtain visas for the T...
# 9         13  Where can I find up-to-date information about ...
# 10        14  Is it advisable for US citizen to attempt a vi...
# 11        15  What are some of the sights to see in Budapest...
# 12        16  Is there a good website to plan a trip via tra...
# 13        25  What are the best ways to avoid data roaming f...
# 14        26  What should I know about "Around The World" fl...
# 15        27  What are some good ways to find things to expl...
# 16        28                 Cheapest mobile operator in Europe
# 17        31                         Sightseeing the USA by air
# 18        33  Online resources/communities especially for tr...
# 19        34  What kind of questions should I be asking abou...
# 20        41                  Where to find good cave-swimming?
# 21        45  Are there advantages to using private car serv...
# 22        47  Are there caves and tunnels under Tallinn, Est...
# 23        66  Is it possible to get a permit to travel to Ti...
# 24        67           What is there to do in Orlando, Florida?
# 25        69  How bad is baggage theft at Johannesburg airport?
# 26        73  Is it safe to travel in Japan considering the ...
# 27        77                           Flight deals from the UK
# 28        78    Tel Aviv a good base to see Israel & Palestine?
# 29        79      Something to do in or around Colmar in France
# ...      ...                                                ...
# 10402  39704                 Key extraction from Plaintext+CMAC
# 10403  39707  Problems when using PBKDF2 to create an ECDSA ...
# 10404  39710           Does AugPake not require key stretching?
# 10405  39711      How exactly does plaintext become ciphertext?
# 10406  39715  Is it safe to use a SSH server keys for a SSH ...
# 10407  39721  What is the next number of this lottery sequence?
# 10408  39722  Hi.. all! CP-ABE implementation in cloud compu...
# 10409  39725  Same-length plaintext results in predictable c...
# 10410  39726  Is there a Fernet implementation for Java or C...
# 10411  39728      Authenticating a message with HMAC vs AES-CBC
# 10412  39730  Help with terms: hash function and a pseudoran...
# 10413  39731    Does passphrase length impact read-write speed?
# 10414  39735          What's a cryptographic primitive, really?
# 10415  39736  Is there a signature scheme in which private k...
# 10416  39737  How to compare security between S-Box and Addi...
# 10417  39739              Selecting an appropriate key for HMAC
# 10418  39741  In A5/1 stream cipher, why are the specific bi...
# 10419  39742          How effective is Serpent-256 in CTR mode?
# 10420  39743                       PBKDF2WithHmacSHA512 in Java
# 10421  39746        Why standard deviation of BLISS is so high?
# 10422  39750    Surely the best Hash would be one nobody knows?
# 10423  39752  Is it possible to use RSA with AEAD operation ...
# 10424  39753  is it possible to extract a "hint hash" of som...
# 10425  39754  Could someone help me to decipher this? I beli...
# 10426  39757                     RSA - twin primes, two modulus
# 10427  39758     Prevent hash collisions with HMAC secret as IV
# 10428  39759  Can a modified executable file be padded to gi...
# 10429  39761                             Definitions of secrecy
# 10430  39762                                 What is a ratchet?
# 10431  39768          Encrypting 256 bit AES keys with AES ECB?
#
#                                                  content  \
# 0      My fiancée and I are looking for a good Caribb...
# 1      This was one of our definition questions, but ...
# 2      Singapore Airlines has an all-business class f...
# 3      Another definition question that interested me...
# 4      A year ago I was reading some magazine, and fo...
# 5      Can anyone suggest the best way to get from Se...
# 6      We are considering visiting Argentina for up t...
# 7      Recently my wife and I traveled to Italy and b...
# 8      I'm planning on taking the trans-Siberian / tr...
# 9      I need to travel from Cusco, Peru to La Paz, B...
# 10     I am aware of travel agencies catering to US c...
# 11     I'm planning my first international trip out o...
# 12     My wife and I have decided to move across Euro...
# 13     I'm looking for data plans I can use while tou...
# 14     I have heard rumours of such things, and have ...
# 15     When traveling, one of my favorite things to d...
# 16      Possible Duplicate: What are the best ways to...
# 17     The next time family from overseas comes to vi...
# 18     I'm dreaming of visiting remote islands such a...
# 19     Tropical destinations have to be one of the mo...
# 20     I'd love to travel to a place that has a good ...
# 21     When planning a trip I've seen people say priv...
# 22     This spring I was in Tallinn, and I heard abou...
# 23     I am confused about how I go about getting a p...
# 24     Aside from the Disney World, what else is ther...
# 25     South Africa's Johannesburg's airport has a re...
# 26     Are there any areas that should be avoided and...
# 27     Can someone recommend a good website with flig...
# 28     I'm planning to spend 3 weeks in Israel & Pale...
# 29     My wife and I will be travelling to Colmar in ...
# ...                                                  ...
# 10402  Can leakage of a plaintext and corresponding a...
# 10403  System based on, e.g.: PBKDF2, ECDSA and authe...
# 10404  I was reading the AugPAKE rfc and noticed that...
# 10405  I'm having a hard time finding out how PlainTe...
# 10406  Let me explain my question. I am working on an...
# 10407  1469356 352428 1413795 1656764 347481 246721 1...
# 10408  I want to know how to implement (deploy)  CP-A...
# 10409  I started with a basic mixed-monoalphabetic su...
# 10410  I want to encrypt user data and exchange it be...
# 10411  Given some string s I want to sign, are follow...
# 10412  I am a little bit confused about the terms has...
# 10413  I'm using Diskcryptor to encrypt a 2TB externa...
# 10414  The more I encounter the term "cryptographic p...
# 10415  Normally in a signature system, the private ke...
# 10416  I'm studying a block cipher based on ARX(Addit...
# 10417  I'm writing a symmetric encryption scheme for ...
# 10418  My two part question is: 1) How are bit positi...
# 10419  I downloaded a compression program known as Pe...
# 10420  I want to encrypt password with PBKDF2WithHmac...
# 10421  In lattice based digital signature scheme BLIS...
# 10422  I'm very confused as to why companys use commo...
# 10423  Some research shows that RSA is commonly used ...
# 10424  I'm a web developer starting to dip into crypt...
# 10425  I have a cipher I have been attempting to solv...
# 10426  I'm working on this problem. I'm given  $\begi...
# 10427  Our organistation would like to hash large fil...
# 10428  MD5 or SHA1 checksums seem to be the gold stan...
# 10429  I found terms like "forward secrecy", "future ...
# 10430  while reading Whatsapp's Security Whitepaper I...
# 10431  What are the pros/cons of using AES ECB mode t...
#
#                                                     tags file_name
# 0                           caribbean cruising vacations    travel
# 1      guides extreme-tourism amazon-river amazon-jungle    travel
# 2      loyalty-programs routes ewr singapore-airlines...    travel
# 3                                 romania transportation    travel
# 4                             extreme-tourism antarctica    travel
# 5                     usa airport-transfer taxis seattle    travel
# 6      sightseeing public-transport transportation ar...    travel
# 7             safety international-travel money exchange    travel
# 8             russia visas china mongolia trans-siberian    travel
# 9      online-resources transportation peru south-ame...    travel
# 10                        us-citizens travel-agents cuba    travel
# 11                          sightseeing hungary budapest    travel
# 12        europe online-resources planning guides trains    travel
# 13     budget cellphones data-plans communication mob...    travel
# 14                           air-travel around-the-world    travel
# 15                    sightseeing planning tourist-traps    travel
# 16             budget europe cellphones mobile-operators    travel
# 17                      air-travel usa sightseeing tours    travel
# 18     online-resources international-travel adventur...    travel
# 19                        planning tropical-destinations    travel
# 20      destinations adventure activities swimming caves    travel
# 21     transportation taxis automobiles airport-transfer    travel
# 22                     sightseeing estonia tallinn caves    travel
# 23                            china trains permits tibet    travel
# 24                                   usa florida orlando    travel
# 25            luggage airports security south-africa jnb    travel
# 26                         health japan safety radiation    travel
# 27        air-travel budget online-resources uk airlines    travel
# 28               israel accommodation palestine tel-aviv    travel
# 29                                       france children    travel
# ...                                                  ...       ...
# 10402                             aes cryptanalysis cmac    crypto
# 10403  public-key cryptanalysis elliptic-curves authe...    crypto
# 10404                           password-hashing augpake    crypto
# 10405                      encryption rsa public-key pgp    crypto
# 10406                             rsa public-key tls ssh    crypto
# 10407                                         randomness    crypto
# 10408                                     implementation    crypto
# 10409                      symmetric substitution-cipher    crypto
# 10410                               encryption symmetric    crypto
# 10411                                 signature hmac mac    crypto
# 10412       hash hmac pseudo-random-function terminology    crypto
# 10413                           key-size disk-encryption    crypto
# 10414                       algorithm-design terminology    crypto
# 10415                               public-key signature    crypto
# 10416                                       block-cipher    crypto
# 10417                                       aes keys mac    crypto
# 10418                                         encryption    crypto
# 10419    encryption symmetric modes-of-operation serpent    crypto
# 10420                                               java    crypto
# 10421  signature post-quantum-cryptography lattice-cr...    crypto
# 10422                                               hash    crypto
# 10423                             rsa modes-of-operation    crypto
# 10424                                               hash    crypto
# 10425                                      cryptanalysis    crypto
# 10426                    rsa cryptanalysis prime-numbers    crypto
# 10427                     hash hmac collision-resistance    crypto
# 10428                                       hash padding    crypto
# 10429                    perfect-secrecy forward-secrecy    crypto
# 10430                                hash diffie-hellman    crypto
# 10431                  encryption aes symmetric key-wrap    crypto
#
# [87000 rows x 5 columns]

# %%
csv.dtypes

# %%
string = csv.iloc[0,0]

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(string, "lxml")
soup.text.replace('\n', ' ')

# %%
csv.content.describe()

# %%
import  nltk
from nltk import regexp_tokenize
from nltk import corpus
from nltk import ngrams
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
sentence = csv.iloc[0, 2]
sentence

# %%
vect=CountVectorizer(stop_words='english')

# %%
from nltk.corpus import stopwords
# ...
filtered_words = [word for word in word_list if word not in stopwords.words('english')]

# %%
patterns = [
    (r'.*ing$', 'VBG'),               # gerunds
    (r'.*ed$', 'VBD'),                # simple past
    (r'.*es$', 'VBZ'),                # 3rd singular present
    (r'.*ould$', 'MD'),               # modals
    (r'.*\'s$', 'NN$'),               # possessive nouns
    (r'.*s$', 'NNS'),                 # plural nouns
    (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  # cardinal numbers
    (r'.*', 'NN')                     # nouns (default)
]

# %%
regexp_tagger = nltk.RegexpTagger(patterns)

# %%
from nltk.corpus import brown

# %%
from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[2007])

# %%
unigram_tagger.tag(sentence)

# %%
n = 2
sixgrams = ngrams(sentence.split(), n)
for grams in sixgrams:
    print grams
